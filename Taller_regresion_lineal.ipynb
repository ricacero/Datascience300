ax.set_ylim(bottom = 0, top=800)#limites de axis
ax.set_title('Rampa Random')#Titulos
ax.set_xlabel('Valores X')
ax.set_ylabel('Valores Y')
ax.scatter(X,y) #dibujamos X y y
x_a = np.asarray(X) #un vector con el mismo numero de datos de X
for c,m,b in zip(['r'],[0.999511],[-20]):
  y_a = m*x_a + b
  ax.plot(x_a,y_a,c=c)

# %% [markdown]
# Postule una m=0.9995112 que es la que se ajusta para un sistema ideal de rampa de acuerdo a la formula para hallar la pendiente m=(y2-y1)/(x2-x1), el valor de b ya lo teniamos como -20 para ejecutar la funcion.

# %%
def prediction(x, b, m):
  return (x*m+b)

def loss(X,  y, b, m):
  sum = 0
  for i in range(len(X)):
    sum += (y[i]-prediction(X[i], b, m))
    #print(y[i]-prediction(X[i], b, m))
  return sum/len(X)

def gradient_regression2(X, y, alpha, b, w):
  aux = -2*(y-(w*X+b)).sum()
  b = b - alpha*aux/float(len(X))
  w = w - alpha*aux/float(len(X))
  return b,w

def gradient_regression(X, y, alpha, b, w):# gradiente diferencia es la resta 
  dw = 0.0
  db = 0.0
  #we make the model by using all the samples
  for i in range(len(X)):
    aux = -2.0*(y[i]-(w*X[i]+b))
    db = db +aux #this solver can overflow
    dw = dw +X[i]*aux
  aux = 1.0/float(len(X))
  b = b - aux*db*alpha
  w = w - aux*dw*alpha
  return b,w

def model(X,y,alpha,b,w,epochs):
  fig = 0
  b_v = []
  w_v = []
  for e in range(epochs):
    b,w = gradient_regression(X, y, alpha, b,w)
    b_v.append(b)
    w_v.append(w)
  return(b_v,w_v)  #print(b,w)


alpha = 0.000004
epochs = 3000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# -18.419601498019603 0.9998076317447943
# loss  -0.017046245634417173

# %%
def prediction(x, b, m):
  return (x*m+b)

def loss(X,  y, b, m):
  sum = 0
  for i in range(len(X)):
    sum += (y[i]-prediction(X[i], b, m))
    #print(y[i]-prediction(X[i], b, m))
  return sum/len(X)

def gradient_regression2(X, y, alpha, b, w):
  aux = -2*(y-(w*X+b)).sum()
  b = b - alpha*aux/float(len(X))
  w = w - alpha*aux/float(len(X))
  return b,w

def gradient_regression(X, y, alpha, b, w):# gradiente diferencia es la resta 
  dw = 0.0
  db = 0.0
  #we make the model by using all the samples
  for i in range(len(X)):
    aux = -2.0*(y[i]-(w*X[i]+b))
    db = db +aux #this solver can overflow
    dw = dw +X[i]*aux
  aux = 1.0/float(len(X))
  b = b - aux*db*alpha
  w = w - aux*dw*alpha
  return b,w

def model(X,y,alpha,b,w,epochs):
  fig = 0
  b_v = []
  w_v = []
  for e in range(epochs):
    b,w = gradient_regression(X, y, alpha, b,w)
    b_v.append(b)
    w_v.append(w)
  return(b_v,w_v)  #print(b,w)

alpha = 0.000002
epochs = 3000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -17.113667972896593 0.9973574721551871
# loss  -0.3441410147093734

# %%
alpha = 0.000003
epochs = 3000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -18.181864142711017 0.9993615949062328
# loss  -0.07659188393769581

# %%
alpha = 0.000004
epochs = 3500000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -18.462668931581717 0.9998884337789806
# loss  -0.0062592247297556325

# %%
alpha = 0.000002
epochs = 3500000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -17.655071473909356 0.9983732397684186
# loss  -0.20853667518258145

# %%
alpha = 0.000003
epochs = 3500000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -18.343414567772186 0.9996646917450489
# loss  -0.036128645983556015

# %%
alpha = 0.000004
epochs = 4000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -18.478482897365435 0.9999181035433056
# loss  -0.002298329793841498

# %%
alpha = 0.000002
epochs = 4000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -17.983141890418516 0.9989887572213461
# loss  -0.12636548111793253

# %%
alpha = 0.000003
epochs = 4000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -159429.01349886158
# -18.419618439715446 0.9998076635303772
# loss  -0.017042002278939625

# %%
fig,ax= plt.subplots(figsize=(12,4))
ax.set_ylim(bottom = 0, top=50)#limites de axis
ax.set_xlim(left = 18, right = 100)
ax.set_title('Rampa Random')#Titulos
ax.set_xlabel('Valores X')
ax.set_ylabel('Valores Y')
ax.scatter(X,y) #dibujamos X y y
x_a = np.asarray(X) #un vector con el mismo numero de datos de X
for c,m,b in zip(['r','y'],[0.999511,0.9999181035433056,],[-20,-18.478482897365435]):
  y_a = m*x_a + b
  ax.plot(x_a,y_a,c=c)
plt.savefig("Ejemplo1.jpg")

# %% [markdown]
# Set de datos de iris.

# %%
iris = load_iris()
#print(iris.DESCR)
datos = pd.DataFrame( iris.data, columns = ['A','B','C','D'])
print(datos['B'].values)

fig,ax= plt.subplots(figsize=(12,4))
ax.set_ylim(bottom = 2, top=5)#limites de axis
ax.set_xlim(left = 0, right = 150)


y=datos['B'].values
X=np.array(range(len(y)))
ax.scatter(X,y)
for c,m,b in zip(['y','r','g','b','k'],[-0.011,-3.834001227963254e-05,-0.004036090492954902 ],[3.70,3.0038210912883114,3.3580220750595835]):
  y = m*X + b
  ax.plot(X,y,c=c)
# Out:
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#  3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#  3.5 3.6 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#  2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
#  2.5 2.8 2.9 3.  2.8 3.  2.9 2.6 2.4 2.4 2.7 2.7 3.  3.4 3.1 2.3 3.  2.5
#  2.6 3.  2.6 2.3 2.7 3.  2.9 2.9 2.5 2.8 3.3 2.7 3.  2.9 3.  3.  2.5 2.9
#  2.5 3.6 3.2 2.7 3.  2.5 2.8 3.2 3.  3.8 2.6 2.2 3.2 2.8 2.8 2.7 3.3 3.2
#  2.8 3.  2.8 3.  2.8 3.8 2.8 2.8 2.6 3.  3.4 3.1 3.  3.1 3.1 3.1 2.7 3.2
#  3.3 3.  2.5 3.  3.4 3. ]

# %%
def prediction(x, b, m):
  return (x*m+b)

def loss(X,  y, b, m):
  sum = 0
  for i in range(len(X)):
    sum += (y[i]-prediction(X[i], b, m))
    #print(y[i]-prediction(X[i], b, m))
  return sum/len(X)

  y=datos['B'].values
for c,m,b in zip(['y','r','g','b','k'],[-0.01,-0.011,-3.834001227963254e-05],[3.75,3.70,3.0038210912883114]):
  ls = loss(X,  y, b, m)
  print("color ",c,ls)
# Out:
# color  y -0.004035239626521196
# color  r 0.12046476037347859
# color  g 0.0

# %%
def prediction(x, b, m):
  return (x*m+b)

def loss(X,  y, b, m):
  sum = 0
  for i in range(len(X)):
    sum += (y[i]-prediction(X[i], b, m))
    #print(y[i]-prediction(X[i], b, m))
  return sum/len(X)

def gradient_regression2(X, y, alpha, b, w):
  aux = -2*(y-(w*X+b)).sum()
  b = b - alpha*aux/float(len(X))
  w = w - alpha*aux/float(len(X))
  return b,w

def gradient_regression(X, y, alpha, b, w):# gradiente diferencia es la resta 
  dw = 0.0
  db = 0.0
  #we make the model by using all the samples
  for i in range(len(X)):
    aux = -2.0*(y[i]-(w*X[i]+b))
    db = db +aux #this solver can overflow
    dw = dw +X[i]*aux
  aux = 1.0/float(len(X))
  b = b - aux*db*alpha
  w = w - aux*dw*alpha
  return b,w

def model(X,y,alpha,b,w,epochs):
  fig = 0
  b_v = []
  w_v = []
  for e in range(epochs):
    b,w = gradient_regression(X, y, alpha, b,w)
    b_v.append(b)
    w_v.append(w)
  return(b_v,w_v)  #print(b,w)

# %%
y=datos['B'].values
X=np.array(range(len(y)))
alpha = 0.0001
epochs = 200000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -29806.94266666667
# 3.3581328466260283 -0.004037201951147677
# loss  -2.7967932192953053e-05

# %%
y=datos['B'].values
X=np.array(range(len(y)))
alpha = 0.0001
epochs = 400000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -29806.94266666667
# 3.3580220796075793 -0.004036090538588521
# loss  -1.1494011135463704e-09

# %%
y=datos['B'].values
X=np.array(range(len(y)))
alpha = 0.0001
epochs = 125000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -29806.94266666667
# 3.362911401973133 -0.0040851489528975
# loss  -0.0012344716489359026

# %%
y=datos['B'].values
X=np.array(range(len(y)))
alpha = 0.00001
epochs = 400000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -29806.94266666667
# 3.7075889391646704 -0.007543569600648488
# loss  -0.0882596705830247

# %%
y=datos['B'].values
X=np.array(range(len(y)))
alpha = 0.0001
epochs = 600000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -29806.94266666667
# 3.3580220750595835 -0.004036090492954902
# loss  -1.1099772952623729e-12

# %%
y=datos['B'].values
X=np.array(range(len(y)))
alpha = 0.0001
epochs = 900000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[10]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
# Out:
# ---------------------------
# color  y -29806.94266666667
# 3.3580220750595835 -0.004036090492954902
# loss  -1.1099772952623729e-12

# %%
fig,ax= plt.subplots(figsize=(12,4))
ax.set_ylim(bottom = 1.5, top=5)#limites de axis
#ax.set_xlim(left = 18, right = 100)
ax.set_title('Iris B')#Titulos
ax.set_xlabel('Valores X')
ax.set_ylabel('Valores Y')


y=datos['B'].values
X=np.array(range(len(y)))
ax.scatter(X,y)
for c,m,b in zip(['y','r','g','b','k'],[-0.011,-3.834001227963254e-05,-0.004036090492954902 ],[3.70,3.0038210912883114,3.3580220750595835]):
  y = m*X + b
 # ax.plot(X,y,c=c)
  if c=='y':
    commen='Mia'
  elif c=='r':
    commen='David'
  elif c=='g':
    commen='IA'

  ax.plot(X, y,c=c,label ="Tendencia " +commen)
ax.legend(loc = "upper right")
plt.savefig("Ejemplo2.jpg")

# %% [markdown]
# Datos en la red, pruebas PCR procesadas en Colombia en Bogota.

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os
import time
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/Bootcamp semana 6'
# Out:
# /content/gdrive/MyDrive/Bootcamp semana 6

# %%
# %%time
pcr = pd.read_csv('Pruebas_PCR_procesadas_de_COVID-19_en_Colombia__Departamental_.csv',sep=";")
# Out:
# CPU times: user 15.1 ms, sys: 6.05 ms, total: 21.1 ms
# Wall time: 629 ms

# %%
#y=pcr['Amazonas'].values
#y_mask=pcr['Amazonas']<=160
#filtered_df = y[y_mask]
#len(filtered_df)

# %%
fig,ax= plt.subplots(figsize=(15,4))
ax.set_ylim(bottom = 1, top=35)#limites de axis
#ax.set_xlim(left = 100, right = 200)
ax.set_xlabel('Dia')
ax.set_ylabel('Pruebas procesadas PCR')
ax.set_title('PCR AMAZONAS')#Titulos

 #y=filtered_df
y=pcr['Amazonas'].values


X=np.array(range(len(y)))
ax.scatter(X,y)
for c,m,b in zip(['r','y','g','b','k'],[0.05],[8]):
  y = m*X + b
  ax.plot(X,y,c=c)
  ax.plot(X, y,c=c,label ="Tendencia al Ojo ")
  ax.legend(loc = "upper right")
  plt.savefig("PCR AMAZONAS10.jpg")

# %%
def prediction(x, b, m):
  return (x*m+b)

def loss(X,  y, b, m):
  sum = 0
  for i in range(len(X)):
    sum += (y[i]-prediction(X[i], b, m))
    #print(y[i]-prediction(X[i], b, m))
  return sum/len(X)

y=pcr['Amazonas'].values
for c,m,b in zip(['y','r','g','b','k'],[0.05],[8]):
  lsp = loss(X,  y, b, m)
  print("color ",c,lsp)
# Out:
# color  y -0.8573317610062908

# %%
def prediction(x, b, m):
  return (x*m+b)

def loss(X,  y, b, m):
  sum = 0
  for i in range(len(X)):
    sum += (y[i]-prediction(X[i], b, m))
    #print(y[i]-prediction(X[i], b, m))
  return sum/len(X)

def gradient_regression2(X, y, alpha, b, w):
  aux = -2*(y-(w*X+b)).sum()
  b = b - alpha*aux/float(len(X))
  w = w - alpha*aux/float(len(X))
  return b,w

def gradient_regression(X, y, alpha, b, w):# gradiente diferencia es la resta 
  dw = 0.0
  db = 0.0
  #we make the model by using all the samples
  for i in range(len(X)):
    aux = -2.0*(y[i]-(w*X[i]+b))
    db = db +aux #this solver can overflow
    dw = dw +X[i]*aux
  aux = 1.0/float(len(X))
  b = b - aux*db*alpha
  w = w - aux*dw*alpha
  return b,w

def model(X,y,alpha,b,w,epochs):
  fig = 0
  b_v = []
  w_v = []
  for e in range(epochs):
    b,w = gradient_regression(X, y, alpha, b,w)
    b_v.append(b)
    w_v.append(w)
  return(b_v,w_v)  #print(b,w)

# %%
y=pcr['Amazonas'].values
X=np.array(range(len(y)))
alpha = 0.000005
epochs = 1500000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[100]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
plt.savefig("PCR AMAZONAS1.jpg")
# Out:
# ---------------------------
# color  y -127076.98233176133
# 12.126172050531794 0.03594354545143355
# loss  -0.5205794923682361

# %%
y=pcr['Amazonas'].values
X=np.array(range(len(y)))
alpha = 0.000005
epochs = 3000000
#print(X)
#print(y)
fig,axbm = plt.subplots(2,1, figsize = (15,20) )
for fig,c,w,b in zip([0,1,],['y','r','g','b','k'],[400],[100]):
  ls = loss(X,  y, b, w)
  print("---------------------------")
  print("color ",c,ls)
  b_v,w_v = model(X,y,alpha,b,w,epochs) 
  
  b_v=b_v[:-500]
  w_v=w_v[:-500]
  z=range(len(b_v))
  axbm[0].plot(z,b_v)
  #axbm[0][fig].set_xlim(left = 0, right = 18)
  #axbm[0][fig].set_ylim(bottom = 4.4905, top = 4.503)
  axbm[1].plot(z,w_v)
  #axbm[1][fig].set_xlim(left = 0, right = 45)
  #axbm[1][fig].set_ylim(bottom = -0.5, top = 1)
print(b_v[-1],w_v[-1])  
print("loss ",loss(X,  y, b_v[-1],w_v[-1]))
plt.savefig("PCR AMAZONAS3m.jpg")
# Out:
# ---------------------------
# color  y -127076.98233176133
# 10.097172556307337 0.04073269558696916
# loss  -0.012135166176334247

# %%
fig,ax= plt.subplots(figsize=(15,4))
ax.set_ylim(bottom = 1, top=35)#limites de axis
#ax.set_xlim(left = 100, right = 200)
ax.set_xlabel('Dia')
ax.set_ylabel('Pruebas procesadas PCR')
ax.set_title('PCR AMAZONAS')#Titulos


y=pcr['Amazonas'].values


X=np.array(range(len(y)))
ax.scatter(X,y)
for c,m,b in zip(['r','y','g','b','k'],[0.05,0.03594354545143355,0.04073269558696916],[8,12.126172050531794,10.097172556307337]):
  y = m*X + b
  if c=='r':
    commen='Mia'
  elif c=='y':
    commen='IA 1.5m'
  elif c=='g':
    commen='IA 3m'
  ax.plot(X,y,c=c)
  ax.plot(X, y,c=c,label ="Tendencia " +commen)
ax.legend(loc = "upper left")
plt.savefig("PCRAMAZONAS.jpg")
