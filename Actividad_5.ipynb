# %% [markdown]
# <a href="https://colab.research.google.com/github/ricacero/Datascience300/blob/main/Actividad_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/bootcamp semana 4/Semana 4'
# Out:
# /content/gdrive/MyDrive/bootcamp semana 4/Semana 4

# %% [markdown]
# 1.Cargar El archivo.

# %%
# %%time
df = pd.read_csv('HRDataset_v14.csv',sep=",")
#pd.read_excel('archivo.xls')
#type(pk)
# Out:
# CPU times: user 15.8 ms, sys: 4.51 ms, total: 20.4 ms
# Wall time: 581 ms

# %% [markdown]
# Sacamos los primeros 20 valores

# %%
df.head(20)
# Out:
#                Employee_Name  EmpID  ...  DaysLateLast30  Absences
# 0        Adinolfi, Wilson  K  10026  ...               0         1
# 1   Ait Sidi, Karthikeyan     10084  ...               0        17
# 2          Akinkuolie, Sarah  10196  ...               0         3
# 3               Alagbe,Trina  10088  ...               0        15
# 4           Anderson, Carol   10069  ...               0         2
# 5          Anderson, Linda    10002  ...               0        15
# 6            Andreola, Colby  10194  ...               0        19
# 7                Athwal, Sam  10062  ...               0        19
# 8           Bachiochi, Linda  10114  ...               0         4
# 9         Bacong, Alejandro   10250  ...               0        16
# 10      Baczenski, Rachael    10252  ...               0        12
# 11           Barbara, Thomas  10242  ...               0        15
# 12          Barbossa, Hector  10012  ...               0         9
# ...

# %% [markdown]
# Revisamos los nombres de las columnas

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %% [markdown]
# Revisamos si tenemos datos nulos en las columnas con que vamos a trabajar.

# %%
df.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# Sacamos estadisticas descriptivas basicas

# %%
df.describe(include='all')
# Out:
#           Employee_Name         EmpID  ...  DaysLateLast30    Absences
# count               311    311.000000  ...      311.000000  311.000000
# unique              311           NaN  ...             NaN         NaN
# top     Guilianno, Mike           NaN  ...             NaN         NaN
# freq                  1           NaN  ...             NaN         NaN
# mean                NaN  10156.000000  ...        0.414791   10.237942
# std                 NaN     89.922189  ...        1.294519    5.852596
# min                 NaN  10001.000000  ...        0.000000    1.000000
# 25%                 NaN  10078.500000  ...        0.000000    5.000000
# 50%                 NaN  10156.000000  ...        0.000000   10.000000
# 75%                 NaN  10233.500000  ...        0.000000   15.000000
# max                 NaN  10311.000000  ...        6.000000   20.000000
#
# [11 rows x 36 columns]

# %% [markdown]
# Realizamos un histograma con los salarios

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.histplot(df['Salary'], kde=True)

# %% [markdown]
# Sacamos los rangos de salarios mas populares

# %%
# !pip install plotly

# %%
import plotly.express as px
fig = px.histogram(df, x="Salary")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="76066f66-df83-4838-ad99-3e3cb3af55a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("76066f66-df83-4838-ad99-3e3cb3af55a9")) {
#                     Plotly.newPlot(
#                         '76066f66-df83-4838-ad99-3e3cb3af55a9',
# ...

# %% [markdown]
# Los rangos de salarios mas populares son los que se encuentran entre 50k-59.9k con 90 personas y 60k-69.9k con 101 personas.

# %% [markdown]
# Graficamos con los salarios discriminados por genero un grafico de violin.

# %%
ax=sns.catplot(data=df,kind='violin',x='Sex',y='Salary',split=True)
ax.set(xlabel='Genero',ylabel='Salarios',title='Salarios discriminado por genero')

# %% [markdown]
# Graficamos una serie de tiempo correspondiente a la fecha de contratacion por año

# %%
df['DateofHire']=pd.to_datetime(df['DateofHire'])
hiring_by_year =df.groupby(df['DateofHire'].dt.to_period('Y')).size()
plt.figure(figsize=(15,6))
hiring_by_year.plot.line()
plt.grid()

# %% [markdown]
# Agrupamos cuantas contrataciones se hicieron por año

# %%
hiring_by_year
# Out:
# DateofHire
# 2006     1
# 2007     2
# 2008     3
# 2009     7
# 2010     9
# 2011    83
# 2012    45
# 2013    44
# 2014    60
# 2015    36
# 2016    14
# 2017     6
# 2018     1
# Freq: A-DEC, dtype: int64
